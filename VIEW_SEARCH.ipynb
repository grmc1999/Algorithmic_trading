# %%
import numpy as np

# %%
rank=np.load("..\Results\SVC_Search_v1\model_2.npy",allow_pickle=True).tolist()
rank
# Out:
# {0: {'Model_type': 'SVC',
#   'train_score': 0.9729241877256317,
#   'test_score': 0.945054945054945,
#   'window': 2,
#   'target_ticker': 'ECL',
#   'input_tickers': ['ALB',
#    'APD',
#    'CE',
#    'CF',
#    'CTVA',
#    'DD',
#    'DOW',
#    'ECL',
#    'EMN',
#    'FCX',
#    'FMC',
#    'IFF',
#    'LIN',
#    'LYB',
#    'MLM',
#    'MOS',
#    'NEM',
#    'NUE',
#    'PPG',
#    'SHW',
#    'VMC'],
#   'C': 10.86},
#  1: {'Model_type': 'SVC',
#   'train_score': 0.9765342960288809,
#   'test_score': 0.9413919413919414,
#   'window': 2,
#   'target_ticker': 'MOS',
#   'input_tickers': ['ALB',
#    'APD',
#    'CE',
#    'CF',
#    'CTVA',
#    'DD',
#    'DOW',
#    'ECL',
#    'EMN',
#    'FCX',
#    'FMC',
#    'IFF',
#    'LIN',
#    'LYB',
#    'MLM',
#    'MOS',
#    'NEM',
#    'NUE',
#    'PPG',
#    'SHW',
#    'VMC'],
#   'C': 19.840000000000003},
#  2: {'Model_type': 'SVC',
#   'train_score': 0.9854545454545455,
#   'test_score': 0.9227941176470589,
# ...

# %%
rank=np.load("..\Results\SVC_Search_v1\model_1.npy",allow_pickle=True).tolist()
for i in rank:
    print(rank[i]["target_ticker"])
    print(rank[i]["test_score"])
# Out:
# ECL
# 0.945054945054945
# ECL
# 0.945054945054945
# ECL
# 0.945054945054945
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ECL
# 0.9413919413919414
# ...

# %%
rank=np.load("..\Results\SVC_Search_v1\model_2.npy",allow_pickle=True).tolist()
for i in rank:
    print(rank[i]["target_ticker"])
    print(rank[i]["test_score"])
    print(rank[i]["window"])
# Out:
# ECL
# 0.945054945054945
# 2
# MOS
# 0.9413919413919414
# 2
# CF
# 0.9227941176470589
# 7
# CF
# 0.9117647058823529
# 6
# CF
# 0.9080882352941176
# 6
# CF
# 0.9044117647058824
# 6
# CF
# 0.9007352941176471
# 6
# CF
# 0.8970588235294118
# 5
# MLM
# 0.8937728937728938
# 3
# SHW
# 0.8937728937728938
# 3
# CF
# 0.8933823529411765
# 5
# SHW
# 0.8901098901098901
# 3
# CF
# 0.8897058823529411
# 5
# SHW
# 0.8827838827838828
# 3
# ALB
# 0.8827838827838828
# 4
# CF
# 0.8827838827838828
# 4
# ALB
# 0.8791208791208791
# 4
# CF
# 0.8791208791208791
# 4
# CTVA
# 0.8791208791208791
# 4
# VMC
# 0.8786764705882353
# 5
# VMC
# 0.875
# 5
# VMC
# 0.8681318681318682
# 4
# CTVA
# 0.8644688644688645
# 4
# VMC
# 0.8644688644688645
# 4
# VMC
# 0.8608058608058609
# 4
# FCX
# 0.8566176470588235
# 5
# FCX
# 0.8529411764705882
# 5
# CF
# 0.8461538461538461
# 4
# CTVA
# 0.8461538461538461
# 4
# LYB
# 0.8461538461538461
# 4
# FCX
# 0.8455882352941176
# 5
# FCX
# 0.8419117647058824
# 5
# FCX
# 0.8345588235294118
# ...

# %%
rank=np.load("..\Results\SVC_Search_v1\model_3.npy",allow_pickle=True).tolist()
for i in rank:
    print(rank[i]["target_ticker"])
    print(rank[i]["test_score"])
    print(rank[i]["window"])
    print(rank[i]["input_tickers"])
# Out:
# ECL
# 0.9197080291970803
# 2
# ['ALB', 'APD', 'CE', 'CF', 'CTVA', 'DD', 'DOW', 'ECL', 'EMN', 'FCX', 'FMC', 'IFF', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PPG', 'SHW', 'VMC']
# NEM
# 0.8795620437956204
# 2
# ['ALB', 'APD', 'CE', 'CF', 'CTVA', 'DD', 'DOW', 'ECL', 'EMN', 'FCX', 'FMC', 'IFF', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PPG', 'SHW', 'VMC']
# VMC
# 0.8722627737226277
# 3
# ['ALB', 'APD', 'CE', 'CF', 'CTVA', 'DD', 'DOW', 'ECL', 'EMN', 'FCX', 'FMC', 'IFF', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PPG', 'SHW', 'VMC']
# MOS
# 0.843065693430657
# 3
# ['ALB', 'APD', 'CE', 'CF', 'CTVA', 'DD', 'DOW', 'ECL', 'EMN', 'FCX', 'FMC', 'IFF', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PPG', 'SHW', 'VMC']
# CF
# 0.8424908424908425
# 4
# ['ALB', 'APD', 'CE', 'CF', 'CTVA', 'DD', 'DOW', 'ECL', 'EMN', 'FCX', 'FMC', 'IFF', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PPG', 'SHW', 'VMC']
# MLM
# 0.8424908424908425
# 4
# ...
